# %%
# !git clone --branch 2025 --single-branch https://github.com/FurioColombo/SeletectedTopics2023ForgerNFX.git /kaggle/working/repo
# %cd /kaggle/working/repo
# !pip install -r requirements.txt

# %%
import os
import yaml
# Inject Kaggle Config
kaggle_config = {"notebook_slug": "forger-nfx-training", "notebook_title": "Forger NFX Training", "device": "cuda", "batch_size": 16, "epochs": 50, "num_workers": 2, "data_root": "/kaggle/input/egfx-dataset", "checkpoint_dir": "/kaggle/working/checkpoints", "metrics_out": "/kaggle/working/metrics.json", "log_dir": "/kaggle/working/logs", "repo_url": "https://github.com/FurioColombo/SeletectedTopics2023ForgerNFX.git", "repo_branch": "2025"}
with open('config/kaggle_train.yaml', 'w') as f:
    yaml.dump(kaggle_config, f)

# %%
# Run Training
# !python train.py --dataset_root /kaggle/input/egfx-dataset --target_folder TubeScreamer --epochs 50 --batch_size 16 --metrics_out /kaggle/working/metrics.json
